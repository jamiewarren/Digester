# %%
# create a test data folders which
# have both from and to tractors
# but do not have any of the images selected for train and validate

# the se are all the tractor images
MIKE_TRACTORS = r'C:\DS Project\Images\Tractors\Mike'
NEIL_TRACTORS = r'C:\DS Project\Images\Tractors\Neil'

#these are the hand picked images that have been used for trainng and validation
MIKE_SELECTED_TRACTORS_FROM =  r'C:\DS Project\Images\Tractors\Mike'
MIKE_SELECTED_TRACTORS_TO =  r'C:\DS Project\Images\Tractors\Mike'

#The directory to be used to copy the test images
MIKE_TRACTOR_TEST = r'C:\DS Project\Images\Tractors\Mike'

# %%
import os
import shutil

# %%
def createFolder(folder):
    
    try:
        os.makedirs(folder)
    except OSError:
        print ("Creation of the directory %s failed" % folder)
    else:
        print ("Successfully created the directory %s " % folder)
   
          
def createTestData(ALL_IMAGES, TRAIN_DATA, TEST_DATA):
    
    #loop round all images and if not in train data copy to test data
    
    for filename in os.listdir(ALL_IMAGES):
    
        picked_to_train = False
    
        #loop for all images manually selected for train/valid
        for subdir, dirs, files in os.walk(TRAIN_DATA):
            for tractorFilename in files:
                if tractorFilename == filename:
                    picked_to_train = True
    
        if picked_to_train == False:
            #copy file to test data
            src = ALL_IMAGES + r'\\' + filename
            dest = TEST_DATA + r'\\' + filename
            
            print (src, dest)
            
            #shutil.copyfile(src, dest)
            
def createTrainAndValidateData(TRAIN_DATA_CLASS_TO, TRAIN_DATA_CLASS_FROM, VALID_DATA_CLASS_TO, VALID_DATA_CLASS_FROM):
    
    # take the manually chosen train data and split
    # between train and validate folders in the required ration
    
    
    #split the To Digester class images into train and validate
    allFileNames = os.listdir(TRAIN_DATA_CLASS_TO)
    np.random.shuffle(allFileNames)
    train_FileNames, val_FileNames = np.split(np.array(allFileNames),[int(len(allFileNames)*0.5)])


#train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
#val_FileNames = [src+'/' + name for name in val_FileNames.tolist()]
#test_FileNames = [src+'/' + name for name in test_FileNames.tolist()]

    print('Total images: ', len(allFileNames))
    print('Training: ', len(train_FileNames))
    print('Validation: ', len(val_FileNames))


    # Copy-pasting images
    for name in train_FileNames:
        shutil.copy(DATA_ROOT + r'\\' + name, "Data2/train"+currentCls)

    for name in val_FileNames:
        shutil.copy(name, "Data2/val"+currentCls)

    for name in test_FileNames:
        shutil.copy(name, "Data2/test"+currentCls)   
        
        
def zipData():
    
    shutil.make_archive('data.zip', 'zip', DATA_ROOT)

# %%
# create folders
createFolder(TEST_DATA)
createFolder(TRAIN_DATA_CLASS_TO)
createFolder(TRAIN_DATA_CLASS_FROM)
createFolder(VALID_DATA_CLASS_TO)
createFolder(VALID_DATA_CLASS_FROM)
print("Folders created")

#Create Test Data
createTestData(ALL_IMAGES, TEST_DATA)
print("Test data created")

#Create Train and Validate Data
createTrainAndValidateData(TRAIN_DATA_CLASS_TO, TRAIN_DATA_CLASS_FROM, VALID_DATA_CLASS_TO, VALID_DATA_CLASS_FROM)
#createTrainAndValidateData(TRAIN_DATA_CLASS_TO, TRAIN_DATA_CLASS_FROM, VALID_DATA_CLASS_TO, VALID_DATA_CLASS_FROM)
#createTrainAndValidateData(TRAIN_DATA_CLASS_TO, TRAIN_DATA_CLASS_FROM, VALID_DATA_CLASS_TO, VALID_DATA_CLASS_FROM)
#createTrainAndValidateData(TRAIN_DATA_CLASS_TO, TRAIN_DATA_CLASS_FROM, VALID_DATA_CLASS_TO, VALID_DATA_CLASS_FROM)
print("Trainging and Validation data created")

#Zip Up
zipData()
print("All zipped up and ready to go")
